# %% [markdown]
# <a href="https://colab.research.google.com/github/xoyeon/SMWU_Big-Data-Analysis/blob/main/data_eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

# 시각화 라이브러리
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 파일 불러오기
df = pd.read_csv("/content/drive/MyDrive/2022-01/빅데이터마이닝/tasks/archive/train_df.csv")

# %%
center = pd.read_csv("/content/drive/MyDrive/2022-01/빅데이터마이닝/tasks/archive/fulfilment_center_info.csv")

# %%
center.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   center_id    77 non-null     int64
#  1   city_code    77 non-null     int64
#  2   region_code  77 non-null     int64
#  3   center_type  77 non-null     object
#  4   op_area      77 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 3.1+ KB

# %%
meal = pd.read_csv("/content/drive/MyDrive/2022-01/빅데이터마이닝/tasks/archive/meal_info.csv")
meal.info()

# %% [markdown]
# - Index : 인덱스
# - Id : 고유번호
# - Week : 1주~145주까지 나타냄
# - Center_id : 각 도시에 있는 물류창고 번호
# - Meal_id : 음식 품목과 종류
# - Checkout_price : 구매가격
# - Base_price : 원가격
# - Emailer_for_promotion : 이메일을 통한 프로모션 유무
# - Homepage_featured : 홈페이지 게재 유무
# -Num_orders : 주문 개수

# %%
df
# Out:
#              id  week  center_id  city_code  region_code center_type  op_area  \
# 0       1379560     1         55        647           56      TYPE_C      2.0
# 1       1466964     1         55        647           56      TYPE_C      2.0
# 2       1346989     1         55        647           56      TYPE_C      2.0
# 3       1338232     1         55        647           56      TYPE_C      2.0
# 4       1448490     1         55        647           56      TYPE_C      2.0
# ...         ...   ...        ...        ...          ...         ...      ...
# 456543  1271326   145         61        473           77      TYPE_A      4.5
# 456544  1062036   145         61        473           77      TYPE_A      4.5
# 456545  1110849   145         61        473           77      TYPE_A      4.5
# 456546  1147725   145         61        473           77      TYPE_A      4.5
# 456547  1361984   145         61        473           77      TYPE_A      4.5
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 456548 entries, 0 to 456547
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   id                     456548 non-null  int64
#  1   week                   456548 non-null  int64
#  2   center_id              456548 non-null  int64
#  3   city_code              456548 non-null  int64
#  4   region_code            456548 non-null  int64
#  5   center_type            456548 non-null  object
#  6   op_area                456548 non-null  float64
#  7   meal_id                456548 non-null  int64
#  8   category               456548 non-null  object
#  9   cuisine                456548 non-null  object
#  10  checkout_price         456548 non-null  float64
#  11  base_price             456548 non-null  float64
#  12  emailer_for_promotion  456548 non-null  int64
#  13  homepage_featured      456548 non-null  int64
# ...

# %%
# 범주형 변수에 대한 값
df.describe(include="object")
# Out:
#        center_type   category  cuisine
# count       456548     456548   456548
# unique           3         14        4
# top         TYPE_A  Beverages  Italian
# freq        262881     127890   122925

# %%
# 중복을 제외한 값에 대한 빈도수
df.nunique()
# Out:
# id                       456548
# week                        145
# center_id                    77
# city_code                    51
# region_code                   8
# center_type                   3
# op_area                      30
# meal_id                      51
# category                     14
# cuisine                       4
# checkout_price             1992
# base_price                 1907
# emailer_for_promotion         2
# homepage_featured             2
# num_orders                 1250
# dtype: int64

# %%
# 카테고리 별 빈도수
sns.countplot(data=df, x='center_type')

# %%
sns.countplot(data=df, x='category')

# %%
sns.countplot(data=df, x='cuisine')

# %%
sns.countplot(data=df, x='emailer_for_promotion')

# %%
sns.countplot(data=df, x='homepage_featured')

# %%
# 각 변수들의 상관관계 파악
plt.figure(figsize = (20,10))
c = df.corr()
sns.heatmap(c, cmap = 'binary', annot = True)

## Checkout_price와 base_price 간 유의미한 상관관계가 있음

# %%
sns.pairplot(df)

# %%
# 원가격 및 구매가격 비교
df[['checkout_price','base_price']].corr()
# Out:
#                 checkout_price  base_price
# checkout_price        1.000000    0.953389
# base_price            0.953389    1.000000

# %%
plt.scatter(df['checkout_price'], df['base_price'])

# %%
df.plot.scatter(x='week', y='checkout_price') 
plt.show()

# %%
df.plot.scatter(x='week', y='base_price') 
plt.show()

# %%
df.plot.scatter(x='category', y='cuisine')
plt.show()

# %% [markdown]
# # 이상치 확인

# %%
sns.boxplot(data=df['num_orders'])
plt.show()

# %%
df['num_orders'].max()
# Out:
# 24299

# %%
sns.boxplot(data=df['checkout_price'])

# %%
sns.boxplot(data=df['base_price'])

# %%
def outlier_iqr(data, column): 

    # lower, upper 글로벌 변수 선언하기     
    global lower, upper    
    
    # 4분위수 기준 지정하기     
    q25, q75 = np.quantile(data[column], 0.25), np.quantile(data[column], 0.75)          
    
    # IQR 계산하기     
    iqr = q75 - q25    
    
    # outlier cutoff 계산하기     
    cut_off = iqr * 1.5          
    
    # lower와 upper bound 값 구하기     
    lower, upper = q25 - cut_off, q75 + cut_off     
    
    print('IQR은',iqr, '이다.')     
    print('lower bound 값은', lower, '이다.')     
    print('upper bound 값은', upper, '이다.')    
    
    # 1사 분위와 4사 분위에 속해있는 데이터 각각 저장하기     
    data1 = data[data[column] > upper]     
    data2 = data[data[column] < lower]    
    
    # 이상치 총 개수 구하기
    return print('총 이상치 개수는', data1.shape[0] + data2.shape[0], '이다.')

# %%
outlier_iqr(df,'num_orders') ## 타겟변수이므로 이상치라고 할 수 있을가?
# Out:
# IQR은 270.0 이다.
# lower bound 값은 -351.0 이다.
# upper bound 값은 729.0 이다.
# 총 이상치 개수는 32937 이다.

# %%
outlier_iqr(df,'base_price')
# Out:
# IQR은 215.37 이다.
# lower bound 값은 -79.555 이다.
# upper bound 값은 781.925 이다.
# 총 이상치 개수는 8 이다.

# %%
outlier_iqr(df,'checkout_price')
# Out:
# IQR은 216.28000000000003 이다.
# lower bound 값은 -95.47000000000008 이다.
# upper bound 값은 769.6500000000001 이다.
# 총 이상치 개수는 1 이다.
