# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install pycaret==2.3.10 markupsafe==2.0.1 pyyaml==5.4.1 -qq
# Out:
#      |████████████████████████████████| 320 kB 4.7 MB/s
#      |████████████████████████████████| 636 kB 3.2 MB/s
#      |████████████████████████████████| 1.7 MB 15.3 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#     Preparing wheel metadata ... done
#      |████████████████████████████████| 167 kB 41.1 MB/s
#      |████████████████████████████████| 1.3 MB 50.0 MB/s
#      |████████████████████████████████| 2.0 MB 42.6 MB/s
#      |████████████████████████████████| 262 kB 53.3 MB/s
#      |████████████████████████████████| 120 kB 49.8 MB/s
#      |████████████████████████████████| 88 kB 7.4 MB/s
#      |████████████████████████████████| 6.8 MB 36.2 MB/s
#      |████████████████████████████████| 56 kB 4.5 MB/s
#      |████████████████████████████████| 17.8 MB 545 kB/s
#      |████████████████████████████████| 1.3 MB 41.6 MB/s
#      |████████████████████████████████| 261 kB 37.3 MB/s
# ...

# %%
import pandas as pd
import numpy as np

# %%
# 파일 불러오기
df = pd.read_csv("/content/drive/MyDrive/2022-01/빅데이터마이닝/tasks/archive/train_df.csv")

# %%
df.columns
# Out:
# Index(['id', 'week', 'center_id', 'city_code', 'region_code', 'center_type',
#        'op_area', 'meal_id', 'category', 'cuisine', 'checkout_price',
#        'base_price', 'emailer_for_promotion', 'homepage_featured',
#        'num_orders'],
#       dtype='object')

# %%
from pycaret.regression import *
# Out:
# /usr/local/lib/python3.7/dist-packages/distributed/config.py:20: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   defaults = yaml.load(f)

# %%
# Categorical 변수를 ordinal_features에 넣어주어 전처리 및 모델 setup
trial2 = setup(data = df, target = 'num_orders',
               ignore_features=['city_code', 'region_code', 'op_area', 'id'],
               bin_numeric_features = ['center_id','meal_id'],
               ordinal_features = {'center_type' : ['TYPE_A', 'TYPE_B', 'TYPE_C'],
                                   'category' : ['Beverages', 'Rice Bowl', 'Starters', 'Pasta', 'Sandwich', 'Biryani', 'Extras', 'Pizza', 'Seafood', 'Other Snacks', 'Desert', 'Soup', 'Salad', 'Fish'],
                                   'cuisine' : ['Thai', 'Indian', 'Italian', 'Continental']})
# Out:
#                                Description             Value
# 0                               session_id              1268
# 1                                   Target        num_orders
# 2                            Original Data      (456548, 15)
# 3                           Missing Values             False
# 4                         Numeric Features                 5
# 5                     Categorical Features                 5
# 6                         Ordinal Features              True
# 7                High Cardinality Features             False
# 8                  High Cardinality Method              None
# 9                    Transformed Train Set      (319583, 48)
# 10                    Transformed Test Set      (136965, 48)
# 11                      Shuffle Train-Test              True
# 12                     Stratify Train-Test             False
# 13                          Fold Generator             KFold
# ...

# %%
top_mod = compare_models()
# Out:
#                                     Model       MAE          MSE      RMSE  \
# rf                Random Forest Regressor   83.8280   34108.2453  184.4503
# et                  Extra Trees Regressor   87.6418   38233.0351  195.2911
# lightgbm  Light Gradient Boosting Machine  104.4297   39462.0380  198.5550
# dt                Decision Tree Regressor  109.2843   59591.5142  243.8293
# knn                 K Neighbors Regressor  119.0812   60322.5939  245.5082
# gbr           Gradient Boosting Regressor  132.6311   66000.8177  256.7883
# lar                Least Angle Regression  177.7065  103642.2391  321.7804
# br                         Bayesian Ridge  177.6946  103642.2391  321.7804
# ridge                    Ridge Regression  177.7046  103642.2372  321.7804
# lr                      Linear Regression  177.7065  103642.2392  321.7804
# lasso                    Lasso Regression  175.6332  104621.8498  323.2979
# ...

# %%
evaluate_model(top_mod)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
predictions = predict_model(top_mod, data = df)
# Out:
#                      Model      MAE         MSE      RMSE      R2   RMSLE  \
# 0  Random Forest Regressor  46.6261  13085.9184  114.3937  0.9165  0.3707
#
#      MAPE
# 0  0.3196

# %%
top_mod
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=-1, oob_score=False,
#                       random_state=1268, verbose=0, warm_start=False)
